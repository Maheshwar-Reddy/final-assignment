# %% [markdown]
# ## Predicting WEST NILE VIRUS in MOSQUITOS, using Random forests.

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#              Date                                            Address  \
# 0      2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1      2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2      2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3      2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4      2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 5      2007-05-29   1500 West Webster Avenue, Chicago, IL 60614, USA
# 6      2007-05-29     2500 West Grand Avenue, Chicago, IL 60654, USA
# 7      2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 8      2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 9      2007-05-29   1100 West Chicago Avenue, Chicago, IL 60642, USA
# 10     2007-05-29    2100 North Stave Street, Chicago, IL 60647, USA
# 11     2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# 12     2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# ...

# %% [markdown]
# ###EDA For each variable in the train.csv (Except name)
# * lets know the following information for each variable
# * Is the variable categorical or continuous
# * Are there missing values?
# * Min, Max, Mean, and Standard Deviation of the continuous variables.
# * Histograms describing the distribution of the variable.

# %% [markdown]
# #### Variable "Date"

# %%
df.Date.value_counts()
# Out:
# 2007-08-01    551
# 2007-08-15    276
# 2013-08-01    186
# 2007-08-24    186
# 2007-08-21    186
# 2007-10-04    185
# 2007-08-07    184
# 2013-07-12    182
# 2013-07-19    182
# 2013-08-08    181
# 2011-07-25    179
# 2011-07-15    177
# 2007-09-24    167
# 2013-08-22    167
# 2009-07-17    164
# ...
# 2007-08-17    54
# 2009-08-27    54
# 2009-06-22    52
# 2007-09-06    50
# 2011-09-02    50
# 2007-06-29    46
# 2007-07-19    45
# 2009-06-15    32
# 2009-06-29    31
# 2007-08-09    26
# 2007-10-09    26
# 2007-05-29    25
# 2007-09-25    23
# 2009-06-03    14
# 2007-08-03     5
# Length: 95, dtype: int64

# %%
df[df.Date.isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Address, Species, Block, Street, Trap, AddressNumberAndStreet, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent]
# Index: []

# %%
df.Date.value_counts().plot(kind='bar')

# %% [markdown]
# #### Variable Date is continuous with no missing values

# %% [markdown]
# #### Variable 'Address'

# %%
df.Address.value_counts()
# Out:
# ORD Terminal 5, O'Hare International Airport, Chicago, IL 60666, USA    750
# South Doty Avenue, Chicago, IL, USA                             542
# South Stony Island Avenue, Chicago, IL, USA                     314
# 4100 North Oak Park Avenue, Chicago, IL 60634, USA              185
# 4200 West 127th Street, Alsip, IL 60803, USA                    183
# 2200 North Cannon Drive, Chicago, IL 60614, USA                 163
# 2400 East 105th Street, Chicago, IL 60617, USA                  160
# 7000 West Armitage Avenue, Chicago, IL 60707, USA               156
# 3700 118th Street, Chicago, IL 60617, USA                       152
# University of Illinois at Chicago, 1100 South Ashland Avenue, Chicago, IL 60607, USA    151
# 5200 South Kolmar Avenue, Chicago, IL 60632, USA                148
# 3500 West 116th Street, Chicago, IL 60655, USA                  147
# 1100 Roosevelt Road, Chicago, IL 60608, USA                     146
# ...

# %%
df[df.Address.isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Address, Species, Block, Street, Trap, AddressNumberAndStreet, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent]
# Index: []

# %%
df.Address.value_counts().plot(kind='bar')

# %% [markdown]
# #### Variable "Address" is categorical with no missing values

# %% [markdown]
# #### Variable "Species"

# %%
df.Species.value_counts()
# Out:
# CULEX PIPIENS/RESTUANS    4752
# CULEX RESTUANS            2740
# CULEX PIPIENS             2699
# CULEX TERRITANS            222
# CULEX SALINARIUS            86
# CULEX TARSALIS               6
# CULEX ERRATICUS              1
# dtype: int64

# %%
df[df.Species.isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Address, Species, Block, Street, Trap, AddressNumberAndStreet, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent]
# Index: []

# %%
df.Species.value_counts().plot(kind='bar')

# %% [markdown]
# #### Variable "Species" is categorical with no missing values

# %% [markdown]
# #### Variable "Block"

# %%
df.Block.value_counts()
# Out:
# 10    1722
# 11     736
# 12     605
# 22     500
# 13     345
# 37     330
# 17     305
# 42     300
# 70     295
# 52     277
# 58     252
# 50     244
# 35     229
# 61     228
# 25     218
# ...
# 49    39
# 81    36
# 96    31
# 73    30
# 68    29
# 20    25
# 98    23
# 93    21
# 66    21
# 47    20
# 27    17
# 80    13
# 34     7
# 55     5
# 29     3
# Length: 64, dtype: int64

# %%
df[df.Block.isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Address, Species, Block, Street, Trap, AddressNumberAndStreet, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent]
# Index: []

# %%
df.Block.value_counts().plot(kind='bar')

# %% [markdown]
# #### Variable "Block" is continuous with no missing values

# %% [markdown]
# #### Variable "Street"

# %%
df.Street.value_counts()
# Out:
#  W OHARE AIRPORT       750
#  S DOTY AVE            542
#  S STONY ISLAND AVE    347
#  S ASHLAND AVE         266
#  N OAK PARK AVE        216
#  W 51ST ST             185
#  W 127TH PL            183
#  N PULASKI RD          173
#  N CANNON DR           172
#  E 105TH ST            160
#   W ARMITAGE AVENUE    156
#  W 95TH ST             154
#  E 118TH ST            152
#  S KOLMAR              148
#  W 116TH ST            147
# ...
#  S WESTERN AVE      17
#  W PERSHING RD      15
#  N TRIPP AVE        15
#  S THROOP           15
#  E RANDOLPH ST      15
#  W GRANVILLE AVE    14
#  W ROSCOE ST        14
#  W 37TH PL.         14
#  W SUNNYSIDE AVE    12
#  S RACINE AVE        8
#  S WALLACE ST        8
#  W 77TH ST           7
#  S LONGWOOD DR       5
#  W 85TH ST           3
#  S HAMLIN AVE        2
# Length: 128, dtype: int64

# %%
df[df.Street.isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Address, Species, Block, Street, Trap, AddressNumberAndStreet, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent]
# Index: []

# %%
df.Street.value_counts().plot(kind='bar')

# %% [markdown]
# #### Variable "Street" is continuous with no missing values

# %% [markdown]
# #### Variable "Trap"

# %%
df.Trap.value_counts()
# Out:
# T900    750
# T115    542
# T138    314
# T002    185
# T135    183
# T054    163
# T128    160
# T151    156
# T212    152
# T090    151
# T114    148
# T158    147
# T048    146
# T031    146
# T903    140
# ...
# T060     15
# T001     15
# T149     14
# T005     14
# T157     14
# T072     13
# T004     12
# T054C     9
# T078      8
# T229      8
# T238      7
# T076      5
# T094B     5
# T237      3
# T040      2
# Length: 136, dtype: int64

# %%
df[df.Trap.isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Address, Species, Block, Street, Trap, AddressNumberAndStreet, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent]
# Index: []

# %%
df.Trap.value_counts().plot(kind='bar')

# %% [markdown]
# #### Variable "Trap" is continuous with no missing values

# %% [markdown]
# #### Variable "AddressNumberAndStreet"

# %%
df.AddressNumberAndStreet.value_counts()
# Out:
# 1000  W OHARE AIRPORT, Chicago, IL       750
# 1200  S DOTY AVE, Chicago, IL            542
# 1000  S STONY ISLAND AVE, Chicago, IL    314
# 4100  N OAK PARK AVE, Chicago, IL        185
# 4200  W 127TH PL, Chicago, IL            183
# 2200  N CANNON DR, Chicago, IL           163
# 2400  E 105TH ST, Chicago, IL            160
# 7000   W ARMITAGE AVENUE, Chicago, IL    156
# 3700  E 118TH ST, Chicago, IL            152
# 1100  S ASHLAND AVE, Chicago, IL         151
# 5200  S KOLMAR, Chicago, IL              148
# 3500  W 116TH ST, Chicago, IL            147
# 1100  W ROOSEVELT, Chicago, IL           146
# 5000  S CENTRAL AVE, Chicago, IL         146
# 1000  W OHARE, Chicago, IL               140
# ...
# 4000  N TRIPP AVE, Chicago, IL                      15
# 2500  S THROOP, Chicago, IL                         15
# 1500  W GRANVILLE AVE, Chicago, IL                  14
# 6000  W ROSCOE ST, Chicago, IL                      14
# 8100  W 37TH PL., Chicago, IL                       14
# ...

# %%
df[df.AddressNumberAndStreet.isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Address, Species, Block, Street, Trap, AddressNumberAndStreet, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent]
# Index: []

# %%
df.AddressNumberAndStreet.value_counts().plot(kind='bar')

# %% [markdown]
# #### Variable "AddressNumberAndStreet" is continuous with no missing values

# %% [markdown]
# #### Variable "Latitude"

# %%
df.Latitude.value_counts()
# Out:
# 41.974689    750
# 41.673408    542
# 41.726465    314
# 41.954690    185
# 41.662014    183
# 41.921965    163
# 41.704572    160
# 41.916265    156
# 41.680946    152
# 41.868077    151
# 41.798697    148
# 41.682587    147
# 41.867108    146
# 41.801498    146
# 41.957799    140
# ...
# 41.846283    15
# 41.953705    15
# 41.942114    14
# 41.825902    14
# 41.994469    14
# 41.747850    13
# 41.962728    12
# 41.925652     9
# 41.753411     8
# 41.775051     8
# 41.753391     7
# 41.719140     5
# 41.794781     5
# 41.738903     3
# 41.852652     2
# Length: 138, dtype: int64

# %%
df[df.Latitude.isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Address, Species, Block, Street, Trap, AddressNumberAndStreet, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent]
# Index: []

# %%
df.Latitude.value_counts().plot(kind='bar')

# %% [markdown]
# #### Variable "Latitude" is continuous with no missing values

# %% [markdown]
# #### Variable "Longitude"

# %%
df.Longitude.value_counts()
# Out:
# -87.890615    750
# -87.599862    542
# -87.585413    314
# -87.800991    185
# -87.724608    183
# -87.632085    163
# -87.565666    160
# -87.800515    156
# -87.535198    152
# -87.666901    151
# -87.736812    148
# -87.707973    147
# -87.654224    146
# -87.763416    146
# -87.930995    140
# ...
# -87.656913    15
# -87.733974    15
# -87.776385    14
# -87.667736    14
# -87.667827    14
# -87.702716    13
# -87.748367    12
# -87.633590     9
# -87.639817     8
# -87.655356     8
# -87.707394     7
# -87.615989     5
# -87.669539     5
# -87.695443     3
# -87.719887     2
# Length: 138, dtype: int64

# %%
df[df.Longitude.isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Address, Species, Block, Street, Trap, AddressNumberAndStreet, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent]
# Index: []

# %%
df.Longitude.value_counts().plot(kind='bar')

# %% [markdown]
# #### Variable "Longitude" is continuous with no missing values

# %% [markdown]
# #### Variable "AddressAccuracy"

# %%
df.AddressAccuracy.value_counts()
# Out:
# 8    4628
# 9    3980
# 5    1807
# 3      91
# dtype: int64

# %%
df[df.AddressAccuracy.isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Address, Species, Block, Street, Trap, AddressNumberAndStreet, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent]
# Index: []

# %%
df.AddressAccuracy.value_counts().plot(kind='bar')

# %% [markdown]
# #### Variable "AddressAccuracy"

# %% [markdown]
# #### Variable "NumMosquitos"

# %%
df.NumMosquitos.value_counts()
# Out:
# 1     2307
# 2     1300
# 50    1019
# 3      896
# 4      593
# 5      489
# 6      398
# 7      326
# 8      244
# 9      237
# 10     206
# 11     170
# 13     163
# 12     132
# 16     128
# 14     120
# 15     112
# 17     107
# 18      92
# 19      86
# 21      85
# 20      79
# 23      69
# 27      67
# 37      61
# 26      57
# 24      57
# 22      56
# 25      50
# 39      49
# 29      48
# 36      47
# 31      47
# 30      44
# 35      43
# 28      43
# 46      43
# 43      39
# 32      39
# 47      37
# 33      36
# 48      36
# 49      35
# 45      35
# 38      35
# 34      31
# 41      31
# 42      29
# 40      28
# 44      25
# dtype: int64

# %%
df[df.NumMosquitos.isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Address, Species, Block, Street, Trap, AddressNumberAndStreet, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent]
# Index: []

# %%
df.NumMosquitos.value_counts().plot(kind='bar')

# %% [markdown]
# #### Variable "NumMosquitos" is categorical with no missing values

# %% [markdown]
# #### Variable "WnvPresent"

# %%
df.WnvPresent.value_counts()
# Out:
# 0    9955
# 1     551
# dtype: int64

# %%
df[df.WnvPresent.isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Address, Species, Block, Street, Trap, AddressNumberAndStreet, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent]
# Index: []

# %%
df.WnvPresent.value_counts().plot(kind='bar')

# %% [markdown]
# #### Variable "WnvPresent" is categorical with no missing values

# %% [markdown]
# #### Hence with the above analysis we can state that there are no missing values in the dataset

# %%
from sklearn.ensemble import RandomForestClassifier

# The error metric. In this case, we will use c-stat (aka ROC/AUC)
from sklearn.metrics import roc_auc_score

# Import the data we need 
X = pd.read_csv("train.csv")
y = X.pop("WnvPresent")

# %%
X.describe()
# Out:
#               Block      Latitude     Longitude  AddressAccuracy  NumMosquitos
# count  10506.000000  10506.000000  10506.000000     10506.000000  10506.000000
# mean      35.687797     41.841139    -87.699908         7.819532     12.853512
# std       24.339468      0.112742      0.096514         1.452921     16.133816
# min       10.000000     41.644612    -87.930995         3.000000      1.000000
# 25%       12.000000     41.732984    -87.760070         8.000000      2.000000
# 50%       33.000000     41.846283    -87.694991         8.000000      5.000000
# 75%       52.000000     41.954690    -87.627796         9.000000     17.000000
# max       98.000000     42.017430    -87.531635         9.000000     50.000000

# %%
# select only the variables that are not "object" datatypes i.e the numeric variables
numeric_variables = list(X.dtypes[X.dtypes != "object"].index)
X[numeric_variables].head()
# Out:
#    Block   Latitude  Longitude  AddressAccuracy  NumMosquitos
# 0     41  41.954690 -87.800991                9             1
# 1     41  41.954690 -87.800991                9             1
# 2     62  41.994991 -87.769279                9             1
# 3     79  41.974089 -87.824812                8             1
# 4     79  41.974089 -87.824812                8             4

# %%
# Drop the variables which seems not so important
X.drop(["Date", "Trap", "Address", "Street", "AddressNumberAndStreet", "AddressAccuracy"], axis=1, inplace=True)

# %%
# Drop the variables which seems not so important
X.drop(["Block"], axis=1, inplace=True)

# %%
categorical_variables = ['Species', 'NumMosquitos']

for variable in categorical_variables:
    # Create array of dummies
    dummies = pd.get_dummies(X[variable], prefix=variable)
    # Update X to include dummies and drop the main variable
    X = pd.concat([X, dummies], axis=1)
    X.drop([variable], axis=1, inplace=True)

# %%
# Make train and test datasets
from sklearn.cross_validation import train_test_split
import numpy as np
np.random.seed(100)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25)

# %%
model = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42)
model.fit(X_train, y_train)

roc = roc_auc_score(y_test, model.predict(X_test))
print "C-stat: ", roc
# Out:
# C-stat:  0.531489426908

# %%
#n_jobs

# %%
# %%timeit
model = RandomForestClassifier(1000, oob_score=True, n_jobs=1, random_state=42)
model.fit(X_train, y_train)
# Out:
# 1 loops, best of 3: 22.7 s per loop

# %%
# %%timeit
model = RandomForestClassifier(1000, oob_score=True, n_jobs=-1, random_state=42)
model.fit(X_train, y_train)
# Out:
# 1 loops, best of 3: 13.4 s per loop

# %%
#n_estimators

# %%
results = []
n_estimator_options = [30, 50, 100, 200, 500, 1000, 2000]

for trees in n_estimator_options:
    model = RandomForestClassifier(trees, oob_score=True, n_jobs=1, random_state=42)
    model.fit(X_train, y_train)
    print trees, "trees"
    roc = roc_auc_score(y_test, model.predict(X_test))
    print "C-stat: ", roc
    results.append(roc)
    print ""
    
pd.Series(results, n_estimator_options).plot();
# Out:
# 30 trees
# C-stat:  0.526618313072
#
# 50
#  trees
# C-stat:  0.527215922634
#
# 100
#  trees
# C-stat:
#  0.531489426908
#
# 200
#  trees
# C-stat:
#  0.523340824735
#
# 500
#  trees
# C-stat:
#  0.523540027922
#
# 1000
#  trees
# C-stat:
#  0.523540027922
#
# 2000
#  trees
# C-stat:
#  0.523540027922

# %%
#max_features

# %%
results = []
max_features_options = ["auto", None, "sqrt", "log2", 0.9, 0.2]

for max_features in max_features_options:
    model = RandomForestClassifier(n_estimators=1000, oob_score=True, n_jobs=1, random_state=42, max_features=max_features)
    model.fit(X_train, y_train)
    print max_features, "option"
    roc = roc_auc_score(y_test, model.predict(X_test))
    print "C-stat: ", roc
    results.append(roc)
    print ""
    
pd.Series(results, max_features_options).plot(kind="barh", xlim=(.85,.99));
# Out:
# auto option
# C-stat:
#  0.523540027922
#
# None
#  option
# C-stat:
#  0.525821500323
#
# sqrt
#  option
# C-stat:
#  0.523540027922
#
# log2
#  option
# C-stat:
#  0.518868117274
#
# 0.9
#  option
# C-stat:
#  0.525821500323
#
# 0.2
#  option
# C-stat:
#  0.523141621548

# %%
#FINAL MODEL

# %%
model = RandomForestClassifier(n_estimators=1000, 
                              oob_score=True, 
                              n_jobs=1, 
                              random_state=42, 
                              max_features="auto", 
                              min_samples_leaf=5)
model.fit(X_train, y_train)
roc = roc_auc_score(y_test, model.predict(X_test)).round(2)
print "C-stat: ", roc
# Out:
# C-stat:  0.5

# %% [markdown]
# ### MODEL COMPARISION

# %% [markdown]
# #### We are 50% successful

# %%
from sklearn.metrics import classification_report
print classification_report(model.predict(X_test), y_test)
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      0.96      0.98      2627
#           1       0.00      0.00      0.00         0
#
# avg / total       1.00      0.96      0.98      2627
# C:\Users\Maheshwar\Anaconda\lib\site-packages\sklearn\metrics\metrics.py:1773: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1])

# %%
# Plot of a ROC curve for a specific class
plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
#Variable importance measures

# %%
model.feature_importances_
# Out:
# array([  2.09106731e-01,   2.16148956e-01,   0.00000000e+00,
#          5.61271038e-02,   2.80961267e-02,   4.22197012e-02,
#          2.80397953e-04,   1.83644177e-07,   9.53192567e-04,
#          6.27235230e-02,   4.23547815e-02,   1.89506523e-02,
#          1.49782688e-02,   6.88793794e-03,   7.91888489e-03,
#          6.51734173e-03,   5.26826596e-03,   6.11577641e-03,
#          6.33591729e-03,   2.84505030e-03,   7.55246469e-03,
#          1.28430608e-02,   7.61139404e-03,   7.32240801e-03,
#          1.11201422e-02,   5.59983242e-03,   8.60547404e-03,
#          1.44615010e-03,   8.64250217e-03,   1.08392481e-02,
#          3.14449469e-03,   4.76783844e-03,   6.75610097e-03,
#          4.17188107e-03,   6.02811546e-03,   6.24625206e-03,
#          1.08651662e-02,   4.28185461e-03,   6.93041548e-03,
#          5.84697275e-03,   9.35038773e-04,   4.16122598e-03,
#          2.48349209e-03,   4.82587071e-03,   6.47557184e-03,
# ...

# %%
# Simple version that shows all of the variables
feature_importances = pd.Series(model.feature_importances_, index=X.columns)
feature_importances.sort()
feature_importances.plot(kind="barh", figsize=(7,6));

# %%
# Complex version that shows the summary view

def graph_feature_importances(model, feature_names, autoscale=True, headroom=0.05, width=10, summarized_columns=None):
    
    if autoscale:
        x_scale = model.feature_importances_.max()+ headroom
    else:
        x_scale = 1
    
    feature_dict=dict(zip(feature_names, model.feature_importances_))
    
    if summarized_columns: 
        #some dummy columns need to be summarized
        for col_name in summarized_columns: 
            #sum all the features that contain col_name, store in temp sum_value
            sum_value = sum(x for i, x in feature_dict.iteritems() if col_name in i )  
            
            #now remove all keys that are part of col_name
            keys_to_remove = [i for i in feature_dict.keys() if col_name in i ]
            for i in keys_to_remove:
                feature_dict.pop(i)
            #lastly, read the summarized field
            feature_dict[col_name] = sum_value
        
    results = pd.Series(feature_dict.values(), index=feature_dict.keys())
    results.sort(axis=1)
    results.plot(kind="barh", figsize=(width,len(results)/4), xlim=(0,x_scale))
    
graph_feature_importances(model, X.columns, summarized_columns=categorical_variables)
